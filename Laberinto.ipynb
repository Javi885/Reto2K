# %%
laberinto = [
    [' ', 'X', 'X', 'X', 'X'],
    [' ', 'X', ' ', ' ', ' '],
    [' ', 'X', ' ', 'X', ' '],
    [' ', ' ', ' ', 'X', ' '],
    ['X', 'X', 'X', 'X', 'S'],
]

# tupla de muros (filas, columnas)
muro = ((0,1), (0,2), (0,3), (0,4),
        (1,1),
        (2,1), (2,3),
        (3,3),
        (4,0), (4,1), (4,2), (4,3))

def imprimir_laberinto(l):
    for fila in l:
        print(''.join(fila))

# Ejemplo de uso:
imprimir_laberinto(laberinto)

movimientos = ['Abajo', 'Abajo', 'Abajo', 'Derecha', 'Derecha', 'Arriba', 'Arriba', 'Derecha', 'Derecha', 'Abajo', 'Abajo', 'Abajo']
# Out:
#  XXXX
#  X
#  X X
#    X
# XXXXS
